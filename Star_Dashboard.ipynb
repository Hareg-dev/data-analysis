# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data=pd.read_csv("/content/6 class csv.csv")
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.3+ KB

# %%
categorical=[col for col in data.columns if data[col].dtype == 'object']
numerical=[col for col in data.columns if data[col].dtype != 'object']
print(data.columns)
print(categorical)
print(numerical)
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Spectral Class'],
#       dtype='object')
# ['Star color', 'Spectral Class']
# ['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)', 'Absolute magnitude(Mv)', 'Star type']

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# Temperature (K)           0
# Luminosity(L/Lo)          0
# Radius(R/Ro)              0
# Absolute magnitude(Mv)    0
# Star type                 0
# Star color                0
# Spectral Class            0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# Length: 240, dtype: bool

# %%
data.nunique()
# Out:
# Temperature (K)           228
# Luminosity(L/Lo)          208
# Radius(R/Ro)              216
# Absolute magnitude(Mv)    228
# Star type                   6
# Star color                 19
# Spectral Class              7
# dtype: int64

# %%
data.shape
# Out:
# (240, 7)

# %%
plt.boxplot(data["Temperature (K)"], vert=False)
plt.ylabel('star type')
plt.xlabel('temprature')
plt.title('Box Plot')
plt.show()

# %%
sns.boxplot(x=data["Luminosity(L/Lo)"])
plt.title(data["Luminosity(L/Lo)"])
plt.show()

# %%
data.describe()
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %%
# calculate summary statistics
mean = data['Luminosity(L/Lo)'].mean()
std  = data['Luminosity(L/Lo)'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
data2= data[(data['Luminosity(L/Lo)'] >= lower_bound)
                & (data['Luminosity(L/Lo)'] <= upper_bound)]
data2.describe()
# Out:
# Lower Bound : -251676.12824582067
# Upper Bound : 466052.85151503736
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       228.000000        228.000000    228.000000
# mean      10015.592105      76535.885054    204.891963
# std        9191.797309     119703.515899    484.511133
# min        1939.000000          0.000080      0.008400
# 25%        3336.000000          0.000802      0.098525
# 50%        5046.000000          0.010500      0.501000
# 75%       14136.250000     170950.000000     31.250000
# max       39000.000000     452000.000000   1783.000000
#
#        Absolute magnitude(Mv)   Star type
# count              228.000000  228.000000
# mean                 5.041763    2.390351
# std                 10.387936    1.682062
# min                -11.920000    0.000000
# 25%                 -5.992500    1.000000
# 50%                 10.635000    2.000000
# 75%                 13.990000    4.000000
# max                 20.060000    5.000000

# %%
data.columns
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Spectral Class'],
#       dtype='object')

# %%
# calculate summary statistics
mean = data['Temperature (K)'].mean()
std  = data['Temperature (K)'].std()

# Calculate the lower and upper bounds
lower_bound = mean - std*2
upper_bound = mean + std*2

print('Lower Bound :',lower_bound)
print('Upper Bound :',upper_bound)

# Drop the outliers
data2= data[(data['Temperature (K)'] >= lower_bound)
                & (data['Temperature (K)'] <= upper_bound)]
data2.describe()
# Out:
# Lower Bound : 0.7600599781891327
# Upper Bound : 0.8072642480134203
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean          0.783662     107188.361635    237.157781
# std           0.011801     179432.244940    517.155763
# min           0.764010          0.000080      0.008400
# 25%           0.773001          0.000865      0.102750
# 50%           0.781262          0.070500      0.762500
# 75%           0.794233     198050.000000     42.750000
# max           0.805843     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type  Star color  Log_Luminosity
# count              240.000000  240.000000  240.000000      240.000000
# mean                 4.382396    2.500000    7.250000        0.707110
# std                 10.532512    1.711394    4.926659        3.964021
# min                -11.920000    0.000000    0.000000       -4.096910
# ...

# %%
# @title Temperature (K)

from matplotlib import pyplot as plt
data2['Temperature (K)'].plot(kind='line', figsize=(8, 4), title='Temperature (K)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
sns.scatterplot(x='Temperature (K)', y='Star type', data=data)
plt.title('Distribution Star type by temprature')
plt.show()

# %%
data.tail()
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 235            38940          374830.0        1356.0                   -9.93
# 236            30839          834042.0        1194.0                  -10.63
# 237             8829          537493.0        1423.0                  -10.73
# 238             9235          404940.0        1112.0                  -11.23
# 239            37882          294903.0        1783.0                   -7.80
#
#      Star type Star color Spectral Class
# 235          5       Blue              O
# 236          5       Blue              O
# 237          5      White              A
# 238          5      White              A
# 239          5       Blue              O

# %%
# @title Temperature (K) vs Luminosity(L/Lo)

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Temperature (K)', y='Luminosity(L/Lo)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.columns
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Log_Luminosity'],
#       dtype='object')

# %%
data['Log_Luminosity'] = data['Luminosity(L/Lo)'].apply(lambda x: np.log10(x) if x > 0 else 0)  # Log scale for luminosity


sns.set(style='darkgrid')


fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle('Star Classification Dashboard', fontsize=16)

sns.scatterplot(data=data, x='Temperature (K)', y='Absolute magnitude(Mv)',hue='Star type',
                palette='deep', ax=axes[0, 0])
axes[0, 0].invert_xaxis()
axes[0, 0].set_title('Hertzsprung-Russell Diagram')

sns.histplot(data=data, x='Temperature (K)',hue='Star type', multiple='stack', ax=axes[0, 1])
axes[0, 1].set_title('Temperature Distribution by Star Type')

sns.boxplot(data=data, x='Star type', y='Log_Luminosity', ax=axes[1, 0])
axes[1, 0].set_title('Log Luminosity by Star Type')
axes[1, 0].tick_params(axis='x', rotation=45)

sns.countplot(data=data, x='Star type', ax=axes[1, 1])
axes[1, 1].set_title('Star Type Counts')
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
data['Temperature (K)'] = np.log(data['Temperature (K)'] + 1)

# Plot original vs transformed
sns.histplot(data['Temperature (K)'], kde=True, color='blue', label='Original')
#sns.histplot(data['log_Temperature (K)'], kde=True, color='green', label='Log Transformed')
plt.legend()
plt.show()

# %%
sns.scatterplot(x='Temperature (K)', y='Absolute magnitude(Mv)', data=data)
plt.title('Scatter Plot of tempartire vs absolute magnitude')
plt.show()

# %%
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le_color=LabelEncoder()
le_class=LabelEncoder()

data["Star color"]=le_color.fit_transform(data["Star color"])
data["Spectral Class"]=le_class.fit_transform(data["Spectral Class"])
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
# ...

# %%
# @title Temperature (K)

from matplotlib import pyplot as plt
data['Temperature (K)'].plot(kind='line', figsize=(8, 4), title='Temperature (K)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
X=data.drop(["Spectral Class"], axis=1)
y=data["Spectral Class"]

# %%
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
scaled_df = pd.DataFrame(scaled_data,
                         columns=data.columns)
print(scaled_df.head())
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0        -0.779382         -0.598624     -0.459210                1.116745
# 1        -0.782110         -0.598624     -0.459241                1.162414
# 2        -0.828477         -0.598624     -0.459342                1.362213
# 3        -0.807496         -0.598624     -0.459229                1.167171
# 4        -0.897819         -0.598624     -0.459340                1.491607
#
#    Star type  Star color  Spectral Class  Log_Luminosity
# 0   -1.46385    0.559354        0.595338       -0.841028
# 1   -1.46385    0.559354        0.595338       -1.013243
# 2   -1.46385    0.559354        0.595338       -1.069326
# 3   -1.46385    0.559354        0.595338       -1.113841
# 4   -1.46385    0.559354        0.595338       -1.154579

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    int64
#  6   Spectral Class          240 non-null    int64
#  7   Log_Luminosity          240 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 15.1 KB

# %%
data
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
# ...

# %%
data['Absolute magnitude(Mv)'].plot(kind='line', figsize=(8, 4), title='Absolute magnitude(Mv)')
plt.gca().spines[['top', 'right']].set_visible(False)
